# %%
import pandas as pd
df = pd.read_csv("E:\PGDM\Self Projects\E-commerce Sales & Customer Insights Analysis using SQL, Python & Power BI\SuperStoreOrders.csv")
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('category')['sales'].sum().sort_values(ascending=False)
# Out:
# category
# Office Supplies    4081206645552763381231353652628147617186140149...
# Technology         3149121931956922316638283924452743881747562,17...
# Furniture          114667211854159691,64838493242,574155262,47998...
# Name: sales, dtype: object

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['sales'] = df['sales'].astype(str).str.replace(',', '')
df['sales'] = df['sales'].astype(float)

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales             float64
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  06-01-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  08-01-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  05-01-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  05-01-2011    Second Class
# 4        IN-2011-47883  01-01-2011  08-01-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  31-12-2014  04-01-2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  05-01-2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  02-01-2015    Second Class
# 51288   MX-2014-114783  31-12-2014  06-01-2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  04-01-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name  sales  quantity  \
# ...

# %%
df.groupby('category')['sales'].sum().sort_values(ascending=False)
# Out:
# category
# Technology         4744691.0
# Furniture          4110884.0
# Office Supplies    3787330.0
# Name: sales, dtype: float64

# %%
df.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.498440      3.476545      0.142908     28.641740      26.375915
# std      487.567175      2.278766      0.212280    174.424113      57.296804
# min        0.000000      1.000000      0.000000  -6599.978000       0.000000
# 25%       31.000000      2.000000      0.000000      0.000000       2.610000
# 50%       85.000000      3.000000      0.000000      9.240000       7.790000
# 75%      251.000000      5.000000      0.200000     36.810000      24.450000
# max    22638.000000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('category')['sales'].sum().plot(kind='bar')
plt.title("Sales by Category")
plt.ylabel("Sales")
plt.show()

# %%
df.groupby('sub_category')['sales'].sum().sort_values(ascending=False)
# Out:
# sub_category
# Phones         1706874.0
# Copiers        1509439.0
# Chairs         1501682.0
# Bookcases      1466559.0
# Storage        1127124.0
# Appliances     1011081.0
# Machines        779071.0
# Tables          757034.0
# Accessories     749307.0
# Binders         461952.0
# Furnishings     385609.0
# Art             372163.0
# Paper           244307.0
# Supplies        243090.0
# Envelopes       170926.0
# Fasteners        83254.0
# Labels           73433.0
# Name: sales, dtype: float64

# %%
df.groupby('region')['sales'].sum().sort_values(ascending=False)
# Out:
# region
# Central           2822399.0
# South             1600960.0
# North             1248192.0
# Oceania           1100207.0
# Southeast Asia     884438.0
# North Asia         848349.0
# EMEA               806184.0
# Africa             783776.0
# Central Asia       752839.0
# West               725514.0
# East               678834.0
# Caribbean          324281.0
# Canada              66932.0
# Name: sales, dtype: float64

# %%
df.groupby('region')['sales'].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %%
df.groupby('category')['profit'].sum()
# Out:
# category
# Furniture          286782.25380
# Office Supplies    518473.83430
# Technology         663778.73318
# Name: profit, dtype: float64

# %%
plt.scatter(df['sales'], df['profit'])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.show()

# %%
plt.scatter(df['sales'], df['profit'])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.show()

# %%
df.groupby('segment')['sales'].sum()
# Out:
# segment
# Consumer       6508141.0
# Corporate      3824808.0
# Home Office    2309956.0
# Name: sales, dtype: float64

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', errors='coerce')

# %%
df.dtypes['order_date']
# Out:
# dtype('<M8[ns]')

# %%
df['order_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['order_date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['month_name'] = df['order_date'].dt.strftime('%b')

# %%
df[['order_date','year','month']].head()
# Out:
#   order_date  year  month
# 0 2011-01-01  2011      1
# 1 2011-01-01  2011      1
# 2 2011-01-01  2011      1
# 3 2011-01-01  2011      1
# 4 2011-01-01  2011      1

# %%
monthly_sales = df.groupby(['year','month'])['sales'].sum().reset_index()

# %%
monthly_sales.head()
# Out:
#    year  month     sales
# 0  2011      1  138245.0
# 1  2011      2  134969.0
# 2  2011      3  171445.0
# 3  2011      4  128843.0
# 4  2011      5  148158.0

# %%
monthly_sales = monthly_sales.sort_values(['year','month'])

# %%
monthly_sales.head()
# Out:
#    year  month     sales
# 0  2011      1  138245.0
# 1  2011      2  134969.0
# 2  2011      3  171445.0
# 3  2011      4  128843.0
# 4  2011      5  148158.0

# %%
monthly_sales
# Out:
#     year  month     sales
# 0   2011      1  138245.0
# 1   2011      2  134969.0
# 2   2011      3  171445.0
# 3   2011      4  128843.0
# 4   2011      5  148158.0
# 5   2011      6  189339.0
# 6   2011      7  162039.0
# 7   2011      8  219236.0
# 8   2011      9  255250.0
# 9   2011     10  204679.0
# 10  2011     11  214931.0
# 11  2011     12  292377.0
# 12  2012      1  162807.0
# 13  2012      2  152663.0
# 14  2012      3  201626.0
# 15  2012      4  187470.0
# 16  2012      5  218953.0
# 17  2012      6  249284.0
# 18  2012      7  174403.0
# 19  2012      8  271675.0
# 20  2012      9  256592.0
# 21  2012     10  239324.0
# 22  2012     11  270725.0
# 23  2012     12  291971.0
# 24  2013      1  206467.0
# 25  2013      2  191077.0
# 26  2013      3  230551.0
# 27  2013      4  233188.0
# 28  2013      5  304523.0
# 29  2013      6  341161.0
# 30  2013      7  223649.0
# 31  2013      8  323889.0
# 32  2013      9  326904.0
# 33  2013     10  270131.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

for year in monthly_sales['year'].unique():
    data = monthly_sales[monthly_sales['year'] == year]
    plt.plot(data['month'], data['sales'], marker='o', label=year)

plt.title('Monthly Sales Trend by Year')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
top_customers = df.groupby('customer_name')['sales'].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# customer_name
# Tom Ashbrook          40489.0
# Tamara Chand          37453.0
# Greg Tran             35552.0
# Christopher Conant    35187.0
# Sean Miller           35170.0
# Bart Watters          32315.0
# Natalie Fritzler      31778.0
# Fred Hopkins          30404.0
# Jane Waco             30288.0
# Hunter Lopez          30246.0
# Name: sales, dtype: float64

# %%
customer_orders = df.groupby('customer_name')['order_id'].nunique().sort_values(ascending=False).head(10)
customer_orders
# Out:
# customer_name
# Frank Olsen         47
# Anna Andreadi       47
# Michael Paige       47
# Kristen Hastings    46
# Laura Armstrong     46
# Sara Luxemburg      46
# Bart Watters        45
# Anthony Rawles      45
# Art Ferguson        45
# Gary Hansen         45
# Name: order_id, dtype: int64

# %%
customer_profit = df.groupby('customer_name')['profit'].sum().sort_values(ascending=False).head(10)
customer_profit
# Out:
# customer_name
# Tamara Chand       8672.89890
# Raymond Buch       8453.04950
# Sanjit Chand       8205.37990
# Hunter Lopez       7816.56778
# Bill Eplett        7410.00530
# Harry Marie        6958.28640
# Susan Pistek       6484.40726
# Mike Gockenbach    6458.67620
# Adrian Barton      6417.28450
# Tom Ashbrook       6311.97910
# Name: profit, dtype: float64

# %%
loss_data = df[df['profit'] < 0]

loss_by_subcategory = loss_data.groupby('sub_category')['profit'].sum().sort_values()
loss_by_subcategory
# Out:
# sub_category
# Tables        -144123.14860
# Bookcases     -101446.29730
# Phones         -96417.66010
# Chairs         -95796.13190
# Machines       -78672.74030
# Storage        -76063.97800
# Copiers        -71547.49982
# Appliances     -63991.69040
# Binders        -52884.06130
# Accessories    -39857.49820
# Furnishings    -28514.49690
# Art            -21660.62770
# Supplies       -18184.43100
# Envelopes      -10863.56550
# Paper          -10299.49370
# Fasteners       -6273.29990
# Labels          -3760.77010
# Name: profit, dtype: float64

# %%
df.groupby('discount')['profit'].mean().sort_values()
# Out:
# discount
# 0.850   -1534.329000
# 0.570    -526.129000
# 0.650    -365.997971
# 0.550    -315.067200
# 0.602    -213.279085
# 0.800    -122.203244
# 0.350    -116.144693
# 0.402    -109.908138
# 0.700    -104.339576
# 0.500     -97.140158
# 0.320     -88.560656
# 0.600     -81.732147
# 0.370     -78.462191
# 0.300     -57.899557
# 0.400     -45.246603
# 0.470     -42.982420
# 0.450     -41.610973
# 0.202     -14.518847
# 0.270      -4.317213
# 0.250       4.043371
# 0.200      23.552594
# 0.170      38.317107
# 0.150      50.602409
# 0.000      61.039514
# 0.100      64.071216
# 0.002     125.762649
# 0.070     140.990022
# Name: profit, dtype: float64

# %%
discount_by_subcat = df.groupby('sub_category')['discount'].mean().sort_values(ascending=False)
discount_by_subcat
# Out:
# sub_category
# Tables         0.290732
# Binders        0.179207
# Machines       0.169583
# Chairs         0.163110
# Bookcases      0.153758
# Furnishings    0.151066
# Phones         0.145847
# Appliances     0.141709
# Fasteners      0.140595
# Storage        0.138464
# Envelopes      0.131749
# Supplies       0.127918
# Accessories    0.120481
# Labels         0.120449
# Art            0.117362
# Copiers        0.117147
# Paper          0.109469
# Name: discount, dtype: float64

# %%
discount_profit = df.groupby('sub_category').agg({
    'discount': 'mean',
    'profit': 'sum'
}).sort_values(by='discount', ascending=False)

discount_profit
# Out:
#               discount        profit
# sub_category
# Tables        0.290732  -64083.38870
# Binders       0.179207   72449.84600
# Machines      0.169583   58867.87300
# Chairs        0.163110  141973.79750
# Bookcases     0.153758  161924.41950
# Furnishings   0.151066   46967.42550
# Phones        0.145847  216717.00580
# Appliances    0.141709  141680.58940
# Fasteners     0.140595   11525.42410
# Storage       0.138464  108461.48980
# Envelopes     0.131749   29601.11630
# Supplies      0.127918   22583.26310
# Accessories   0.120481  129626.30620
# Labels        0.120449   15010.51200
# Art           0.117362   57953.91090
# Copiers       0.117147  258567.54818
# Paper         0.109469   59207.68270

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(df['discount'], df['profit'])
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
df.to_csv("cleaned_superstore.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv("cleaned_superstore.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
df.to_csv("data/cleaned_superstore.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_csv("data/cleaned_superstore.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("E:\PGDM\Self Projects\E-commerce Sales & Customer Insights Analysis using SQL, Python & Power BI\SuperStoreOrders.csv")

# %%
df.to_csv("E:\PGDM\Self Projects\E-commerce Sales & Customer Insights Analysis using SQL, Python & Power BI\cleaned_superstore.csv", index=False)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...
